# %% [markdown]
# В этой главе вы научились определять словари и работать с хранящейся в них
# информацией. Вы узнали, как обращаться к отдельным элементам словаря и из-
# менять их, как перебрать всю информацию в словаре. Вы научились перебирать
# пары «ключ—значение», ключи и значения словаря. Также были рассмотрены воз-
# можности вложения словарей в список, вложения списков в словари и вложения
# словарей в другие словари.
# В следующей главе будут рассмотрены циклы while и получение входных данных
# от пользователей программ. Эта глава будет особенно интересной, потому что вы
# наконец-то сможете сделать свои программы интерактивными: они начнут реаги-
# ровать на действия пользователя.

# %%
alien_0 = {'color': 'geen', 'point': 5 }
print(alien_0['color'])
print(alien_0['point'])

new_proints = alien_0['point']
print("You just earned " + str(new_proints) + " points")

# %%
alien_0 = {'color': 'green', 'point': 5}
print(alien_0)

alien_0['x_position'] = 0
alien_0['y_position'] = 25
print(alien_0)

# %%
alien_0 = {'x_position': 0, 'y_position': 25, 'speed': 'fast'}
print('Original x-position: ' + str(alien_0['x_position']))

# Пришелец перемещается вправо
# Вычисляем величину перемещения на основании текущей скорости 

if alien_0['speed'] == 'slow':
    x_increment = 1
elif alien_0['speed'] == 'medium':
    x_increment = 2
else:
    # Пришелец двигается быстро 
    x_increment = 3
# Новая позиция равна сумме старой позиции и приращения 

alien_0['x_position'] = alien_0['x_position'] + x_increment
print("New x-position: " + str(alien_0['x_position']))

# %%
alien_0 = {'color': 'green', 'points': 5}
del alien_0['points']
print(alien_0)

# %%
me = {'old': 29, 
    'weight': 70,
    'heigh': 167,
    'first_name': 'vova',
    'second_name': 'chupin',
    }
print(me)

# %%
favorite_numbers = {
    'john': 1,
    'ivan': 2,
    'keks': 3,
    'level': 4,
    'krut': 5,
    }
print("John's favorite number is " + str(favorite_numbers['john']))
print("Ivan's favorite number is " + str(favorite_numbers['ivan']))
print("Keks's favorite number is " + str(favorite_numbers['keks']))
print("Level's favorite number is " + str(favorite_numbers['level']))
print("Krut's favorite number is " + str(favorite_numbers['krut']))

# %%
user_0 = {
    'username': 'vs_chupin',
    'first': 'vladimir',
    'last': 'chupin',
    }

# %%
favorite_language = {
    'jen': 'python',
    'sarah': 'c++',
    'john': 'js',
    'pavel': 'python',
    }
# print("Sarah's favorite language is " + 
#     favorite_language['sarah'].title() + 
#     ".")

# for name, language in favorite_language.items():
#     print(name.title() + "'s favorite language is " +
#         language.title() + ',')

# for name in favorite_language.keys():
#     print(name.title())
# print("\n")    
# for language in favorite_language.values():
#     print(language.title())

friends = ['jen', 'pavel']
for name in favorite_language.keys():
    print("\n" + name.title())
    
    if name in friends: 
        print(" Hi " + name.title() + 
            ", I see your favorite lang is " +
            favorite_language[name].title() + "!")   

if 'dmitry' not in favorite_language.keys():
    print("\nDmitry, please take our poll!\n")

for name in sorted(favorite_language.keys()):
    print(name.title() + ", thank you for taking poll.")
    
print("\nThe following language have been mentioned:")
for language in favorite_language.values():
    print(language.title())

print("\nThe following language have been mentioned:")
for language in set(favorite_language.values()):
    print(language.title())

# %%
glossary = {
    'Список': 'набор элементов, следующих в определенном порядке.',
    'Кортеж': "На языке Python значения, которые не могут изменяться, называются неизменяемыми 'immutable', а неизменяемый список называется кортежем.",
    'Команды if': 'Простейшая форма команды if состоит из одного условия и одного действия.',
    'PEP 8': '(Python Enhancement Proposal) - Руководство по стилю Python.',
    'Словарь': 'структурах данных, предназначенных для объединения взаимосвязанной информации.',
    }
# print("Список, это: " +
#     "\n- " +
#     (glossary['Список']))

# print("\n")

# print("Кортеж, это: " +
#     "\n- " +
#     (glossary['Кортеж']))

# print("\n")

# print("Команды if, это: " +
#     "\n- " +
#     (glossary['Команды if']))

# print("\n")

# print("PEP 8, это: " +
#     "\n- " +
#     (glossary['PEP 8']))

# print("\n")

# print("Словарь, это: " +
#     "\n- " +
#     (glossary['Словарь']))

# Оптимизированный вариант 
for name, value in glossary.items():
    print(name.title() + ":\n" + "- " + value)

# %%
rivers = {'volga': 'russia', 'nil': 'egypt','temza': 'great britain', 'amazonka': 'america'}
for river, county in rivers.items():
    print("The " + river.title()
        + " runs through " + county.title() + ".")

print('\n')
    
for river in rivers:
    print(river.title())

print('\n')

for country in rivers.values():
    print(country.title())

# %%
favorite_language = {
    'jen': 'python',
    'sarah': 'c++',
    'john': 'js',
    'pavel': 'python',
    }

poll_ppl = ['henry', 'micle', 'jen', 'john']
for ppl in poll_ppl:
    if ppl in favorite_language:
        print("Hi, " + ppl.title() + ", I see that you took part in the survey, thank you.")
    else:
        print("Hi, " + ppl.title() + ", please take part in the survey.")

# %%
aliens = []
for alien_number in range(30):
    new_alien = {'color': 'green', 'point': 5, 'speed': 'slow'}
    aliens.append(new_alien)
    
for alien in aliens[:5]:
    print(alien)
print('...')

print("Total number of aliens: " + str(len(aliens)))

for alien in aliens[0:3]:
    if alien['color'] == 'green':
        alien['color'] = 'yellow'
        alien['point'] = 10
        alien['speed'] = 'medium'

for alien in aliens[:5]:
    print(alien)

# %%
pizza = {
    'crust': 'thick',
    'toppings': [
        'mushrooms',
        'extra cheese',
    ]
}

print("You ordered a " + pizza['crust'] + "-crust pizza " +
    "with the following toppings:")
for topping in pizza['toppings']:
    print('\t' + topping)

# %%
favorite_languages = {
    'john': ['ruby', 'c++'],
    'sarah': ['python', 'c'],
    'pavel': ['c#']
    }

for name, languages in favorite_languages.items():
    if len(languages) == 1:
        print("\n" + name.title() + "'s favirite language is " + str.title(languages[0]))
    else:
        print("\n" + name.title() + "'s favorite languages are:")
        for language in languages:
            print("\t" + language.title())

# %%
users = {
    'vschupin': {
        'first': 'vova',
        'last': 'chupin',
        'location': 'Yaroslavl',
    },
    'evanna': {
        'first': 'anna',
        'last': 'evdokimycheva',
        'location': 'Yaroslavl',
    },
}

for login, users_info in users.items():
    print("\nLogin: " + login)
    full_name = users_info['first'] + " " + users_info['last']
    loca = users_info['location']
    print("\tFull name: " + full_name.title())
    print("\tLocation: " + loca.title())

# %%
people = {
    'pasha': {
        'first_name': 'pavel',
        'last_name': 'kolens',
        'age': 24,
        'city': 'london',
    },
    'varya': {
        'first_name': 'varvara',
        'last_name': 'bosco',
        'age': 44,
        'city': 'moscow',
    },
    'kolya': {
        'first_name': 'nicolai',
        'last_name': 'bivis',
        'age': 44,
        'city': 'new york',
    },
}

for name, user_info in people.items():
    print("\nName: " + name.title()) 
    full_name = user_info['first_name'].title() + " " + user_info['last_name'].title() 
    age = user_info['age']
    city = user_info['city']
    print("user data: " + 
        '\n\t' +
        full_name +
        '\n\t' +
        str(age) + 
        '\n\t' +
        str.title(city)
    )

# %%
pets = {
    'arishka': {
        'animal': 'cat',
        'owner': 'vova',
    },
    'redzhina': {
        'animal': 'cat',
        'owner': 'ivan',
    },
    'popas': {
        'animal': 'dog',
        'owner': 'john',
    },
}

for name, pet_info in pets.items():
    print("\nThe nickname: " + name.title() + '\ninfo: ')
    animal = pet_info['animal']
    owner = pet_info['owner']
    print('\tanimal: ' + str(animal) +
        '\n\towner: ' + str.title(owner))

# %%
favorite_places = {
    'ivan': ['Moscow', 'Saint Petersburg', 'Novosibirsk'],
    'anna': ['New York', 'London', 'Tokyo'],
    'petr': ['Paris', 'Berlin', 'Rome']
}

for person, places in favorite_places.items():
    print(f"\n{person.title()}'s favorite places:")
    for place in places:
        print(f'\t{place}')

# %%
favorite_numbers = {
    'john': [
        '1',
        '2',
        '3',
    ],
    'ivan': [
        '4',
        '5',
        '6',
    ],
    'luci': [
        '7',
        '8',
        '9',
    ],
}

for name, f_nums in favorite_numbers.items():
    print(f"\n{name.title()}'s favotite numbers:")
    for f_num in f_nums:
        print(f"\t{f_num}")

# %%
cities = {
    'yaroslavl': {
        'country': 'russia',
        'population': 570000,
        'fact': 'Yaroslavl is emblazoned on a 1,000-ruble bill.',
    },
    'new york': {
        'country': 'usa',
        'population': 8000000,
        'fact': 'In New York, they easily cross the road at a red light and no one cares.',
    },
    'minsk': {
        'country': 'belarussia',
        'population': 2000000,
        'fact': 'Minsk is older than Moscow — it was founded in 1067, almost a thousand years ago.',
    },
}

for city, city_info in cities.items():
    print(f"\n{city.title()} info: ")
    country = city_info['country']
    popul = city_info['population']
    fact = city_info['fact']
    print(f"\tCounty: {country.title()}\n\tPopulation: {popul}\n\tFact: {fact}")
# Out:
# Yaroslavl info:
# 	County: Russia
# 	Population: 570000
# 	Fact: Yaroslavl is emblazoned on a 1,000-ruble bill.
#
# New York info:
# 	County: Usa
# 	Population: 8000000
# 	Fact: In New York, they easily cross the road at a red light and no one cares.
#
# Minsk info:
# 	County: Belarussia
# 	Population: 2000000
# 	Fact: Minsk is older than Moscow — it was founded in 1067, almost a thousand years ago.
